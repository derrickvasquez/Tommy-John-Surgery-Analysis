# %%
# Importing Data from @MLBPlayerAnalysis

import pandas as pd
import csv

df = pd.read_csv('Tommy John Surgery List (@MLBPlayerAnalys) - TJ List.csv', index_col=1)
df
# Out:
#                         Player Team Level Position Throws        Country  \
# TJ Surgery Date
# 11/23/2022        Bryce Harper  PHI   MLB       OF      R  United States
# 10/12/2022        Tyler Matzek  ATL   MLB        P      L  United States
# 10/1/2022        Scott Effross  NYY   MLB        P      R  United States
# 9/28/2022            Shane Baz   TB   MLB        P      R  United States
# 9/14/2022         Anthony Gose  CLE   MLB        P      L  United States
# ...                        ...  ...   ...      ...    ...            ...
# 10/13/1981       Tom Candiotti  MIL    AA        P      R  United States
# 4/13/1981         Bill Bordley   SF   MLB        P      L  United States
# 1/1/1981           Joe Hesketh  WAS    AA        P      L  United States
# 1/1/1978           Brent Strom   SD   MLB        P      L  United States
# 9/25/1974           Tommy John  LAD   MLB        P      L  United States
#
#                 High School                College(s)  Age  \
# ...

# %%
# Cleaning data, and removing columns that I won't be using for this analysis
updated_df = df.drop(df.iloc[:, 8:], axis=1)
updated_df
# Out:
#                         Player Team Level Position Throws        Country  \
# TJ Surgery Date
# 11/23/2022        Bryce Harper  PHI   MLB       OF      R  United States
# 10/12/2022        Tyler Matzek  ATL   MLB        P      L  United States
# 10/1/2022        Scott Effross  NYY   MLB        P      R  United States
# 9/28/2022            Shane Baz   TB   MLB        P      R  United States
# 9/14/2022         Anthony Gose  CLE   MLB        P      L  United States
# ...                        ...  ...   ...      ...    ...            ...
# 10/13/1981       Tom Candiotti  MIL    AA        P      R  United States
# 4/13/1981         Bill Bordley   SF   MLB        P      L  United States
# 1/1/1981           Joe Hesketh  WAS    AA        P      L  United States
# 1/1/1978           Brent Strom   SD   MLB        P      L  United States
# 9/25/1974           Tommy John  LAD   MLB        P      L  United States
#
#                 High School                College(s)
# TJ Surgery Date
# ...

# %%
# Creating new .csv file to reflect the cleaned data

updated_df.to_csv('Updated Tommy John Surgery List (@MLBPlayerAnalys).csv', encoding='utf-8', index=True)
